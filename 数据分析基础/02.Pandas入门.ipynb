# %%
import pandas as pd

df=pd.DataFrame([
    {"姓名": "小王", "语文": 90, "数学": 80, "英语": 70},
    {"姓名": "小李", "语文": 80, "数学": 90, "英语": 80},
    {"姓名": "小张", "语文": 70, "数学": 80, "英语": 90},
    {"姓名": "小赵", "语文": 60, "数学": 70, "英语": 80},
    {"姓名": "小孙", "语文": 80, "数学": 90, "英语": 70},
    {"姓名": "小李", "语文": 80, "数学": 80, "英语": 90},
    {"姓名": "小刘", "语文": 90, "数学": 80, "英语": 80},
    {"姓名": "小罗", "语文": 65, "数学": 55, "英语": 99},
    {"姓名": "小周", "语文": 91, "数学": 78, "英语": 82}
])

# Jupyter只输出单元格最后一行的变量/表达式
df
# Out:
#    姓名  语文  数学  英语
# 0  小王  90  80  70
# 1  小李  80  90  80
# 2  小张  70  80  90
# 3  小赵  60  70  80
# 4  小孙  80  90  70
# 5  小李  80  80  90
# 6  小刘  90  80  80
# 7  小罗  65  55  99
# 8  小周  91  78  82

# %%
#Dataframe是一个表格，它的每一列都是一个series。
#但series是独立于Dataframe的，可以单独创建，不是伴随Dataframe生成的副产物
df['语文']
# Out:
# 0    90
# 1    80
# 2    70
# 3    60
# 4    80
# 5    80
# 6    90
# 7    65
# 8    91
# Name: 语文, dtype: int64

# %%
print(f"语文最高分为：{df['语文'].max()}，最低分为：{df['语文'].min()},平均分为：{df['语文'].mean():.2f}")
print(f"数学最高分为：{df['数学'].max()}，最低分为：{df['数学'].min()},平均分为：{df['数学'].mean():.2f}")
print(f"英语最高分为：{df['英语'].max()}，最低分为：{df['英语'].min()},平均分为：{df['英语'].mean():.2f}")
# Out:
# 语文最高分为：91，最低分为：60,平均分为：78.44
# 数学最高分为：90，最低分为：55,平均分为：78.11
# 英语最高分为：99，最低分为：70,平均分为：82.33
